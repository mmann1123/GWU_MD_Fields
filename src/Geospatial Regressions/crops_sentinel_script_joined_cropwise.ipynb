# %% [markdown]
# # set up data stacks

# %%
import geopandas as gpd
import pandas as pd
import os
from glob import glob


May_Sep_S2_2019 = ['./May_Sep_S2/evi__abs_energy__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__absolute_sum_of_changes__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__autocorr_lag_1_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__autocorr_lag_2_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__autocorr_lag_4_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__count_above_mean__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__count_below_mean__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__doy_of_maximum_first_band_evi_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__doy_of_maximum_last_band_evi_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__doy_of_minimum_first_band_evi_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__doy_of_minimum_last_band_evi_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__kurtosis__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__linear_time_trend__intercept_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__linear_time_trend__pvalue_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__linear_time_trend__rvalue_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__linear_time_trend__slope_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__longest_strike_above_mean__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__longest_strike_below_mean__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__maximum__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__mean__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__mean_abs_change__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__mean_change__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__mean_second_derivative_central__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__median__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__minimum__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__quantile_q_0.05_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__quantile_q_0.95_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__ratio_beyond_r_sigma_r_1_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__ratio_beyond_r_sigma_r_2_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__ratio_beyond_r_sigma_r_3_may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__ratio_value_number_to_time_series_length__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__skewness__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__standard_deviation__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__sum_values__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__symmetry_looking__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__ts_complexity_cid_ce__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__variance__may_sep_2019.tif'
                   ,'./May_Sep_S2/evi__variance_larger_than_standard_deviation__may_sep_2019.tif']
                   

May_Sep_S2_2020 = ['./May_Sep_S2/evi__abs_energy__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__absolute_sum_of_changes__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__autocorr_lag_1_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__autocorr_lag_2_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__autocorr_lag_4_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__count_above_mean__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__count_below_mean__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__doy_of_maximum_first_band_evi_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__doy_of_maximum_last_band_evi_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__doy_of_minimum_first_band_evi_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__doy_of_minimum_last_band_evi_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__kurtosis__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__linear_time_trend__intercept_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__linear_time_trend__pvalue_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__linear_time_trend__rvalue_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__linear_time_trend__slope_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__longest_strike_above_mean__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__longest_strike_below_mean__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__maximum__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__mean__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__mean_abs_change__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__mean_change__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__mean_second_derivative_central__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__median__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__minimum__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__quantile_q_0.05_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__quantile_q_0.95_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__ratio_beyond_r_sigma_r_1_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__ratio_beyond_r_sigma_r_2_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__ratio_beyond_r_sigma_r_3_may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__ratio_value_number_to_time_series_length__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__skewness__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__standard_deviation__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__sum_values__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__symmetry_looking__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__ts_complexity_cid_ce__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__variance__may_sep_2020.tif'
                   ,'./May_Sep_S2/evi__variance_larger_than_standard_deviation__may_sep_2020.tif']               
                   

May_Sep_S2_2021 = ['./May_Sep_S2/evi__abs_energy__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__absolute_sum_of_changes__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__autocorr_lag_1_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__autocorr_lag_2_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__autocorr_lag_4_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__count_above_mean__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__count_below_mean__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__doy_of_maximum_first_band_evi_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__doy_of_maximum_last_band_evi_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__doy_of_minimum_first_band_evi_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__doy_of_minimum_last_band_evi_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__kurtosis__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__linear_time_trend__intercept_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__linear_time_trend__pvalue_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__linear_time_trend__rvalue_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__linear_time_trend__slope_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__longest_strike_above_mean__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__longest_strike_below_mean__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__maximum__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__mean__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__mean_abs_change__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__mean_change__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__mean_second_derivative_central__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__median__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__minimum__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__quantile_q_0.05_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__quantile_q_0.95_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__ratio_beyond_r_sigma_r_1_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__ratio_beyond_r_sigma_r_2_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__ratio_beyond_r_sigma_r_3_may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__ratio_value_number_to_time_series_length__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__skewness__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__standard_deviation__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__sum_values__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__symmetry_looking__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__ts_complexity_cid_ce__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__variance__may_sep_2021.tif'
                   ,'./May_Sep_S2/evi__variance_larger_than_standard_deviation__may_sep_2021.tif']

# %%
#May_Sep_S2_2019
#May_Sep_S2_2020
#May_Sep_S2_2021

# %%
# !mkdir May_Sep_S2_result -p
import geowombat as gw
import os

# %% [markdown]
# ## Create image stacks with time series variables

# %%
with gw.open(May_Sep_S2_2019,stack_dim="band",band_names=['abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','autocorr_lag_4','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation'],) as src_2019:
    print(src_2019)

# %%
with gw.open(May_Sep_S2_2020,stack_dim="band",band_names=['abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','autocorr_lag_4','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation'],) as src_2020:
    print(src_2020)

# %%
with gw.open(May_Sep_S2_2021,stack_dim="band",band_names=['abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','autocorr_lag_4','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation'],) as src_2021:
    print(src_2021)

# %% [markdown]
# # Read in point yeild data

# %%
sdf_2019 = gpd.read_file("./data/crops_2019/crops2019_shapefile.shp") 
sdf_2020 = gpd.read_file("./data/crops_2020/crops2020_shapefile.shp") 
sdf_2021 = gpd.read_file("./data/crops_2021/crops2021_shapefile.shp") 

sdf_2019.head()
#sdf_2020.head()
#sdf_2021.head()

# %%
sdf_2019.columns

# %% [markdown]
# ## Create common codes for fields and products

# %%
from sklearn.preprocessing import LabelEncoder


# double check this I don't think its right

labelencoder = LabelEncoder()

sdf_2019['Field_Cat'] = labelencoder.fit_transform(sdf_2019['Field'])
sdf_2019['Product_Cat'] = labelencoder.fit_transform(sdf_2019['Product'])

sdf_2020['Field_Cat'] = labelencoder.fit_transform(sdf_2020['Field'])
sdf_2020['Product_Cat'] = labelencoder.fit_transform(sdf_2020['Product'])


sdf_2021['Field_Cat'] = labelencoder.fit_transform(sdf_2021['Field'])
sdf_2021['Product_Cat'] = labelencoder.fit_transform(sdf_2021['Product'])

# %%
sdf_2019 = sdf_2019[['Field','Field_Cat','Product','Product_Cat','geometry','yield']]
sdf_2020 = sdf_2020[['Field','Field_Cat','Product','Product_Cat','geometry','yield']]
sdf_2021 = sdf_2021[['Field','Field_Cat','Product','Product_Cat','geometry','yield']]

# %%
sdf_2019.head()
#sdf_2020.head()
#sdf_2021.head()

# %% [markdown]
# # Extract time series data to points

# %%
with gw.open(May_Sep_S2_2019,stack_dim="band",band_names=['abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','autocorr_lag_4','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation'],) as src_2019:
    df_2019 = src_2019.gw.extract(sdf_2019,band_names=src_2019.band.values.tolist())
    
print(df_2019)

with gw.open(May_Sep_S2_2020,stack_dim="band",band_names=['abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','autocorr_lag_4','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation'],) as src_2020:
    df_2020 = src_2020.gw.extract(sdf_2020,band_names=src_2020.band.values.tolist())
    
#print(df_2020)

with gw.open(May_Sep_S2_2021,stack_dim="band",band_names=['abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','autocorr_lag_4','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation'],) as src_2021:
    df_2021 = src_2021.gw.extract(sdf_2021,band_names=src_2021.band.values.tolist())
    
#print(df_2021)

# %%
df_2019.head()
#df_2020.head()
#df_2021.head()

# %%
type(df_2019)

# %%
df_2019.dtypes

# %%
df_2019 = df_2019[['geometry','Field','Field_Cat','Product','Product_Cat','abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','autocorr_lag_4','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation','yield']]

# %%
df_2019.head()

# %%
len(df_2019)

# %%
df_2019.isna().sum()

# %%
df_2019.dtypes

# %% [markdown]
# # Create a single field polygon dataset

# %%
from glob import glob
from os import path

airstrip_east_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/University of Md._Aspen_Wye Angus/Boundary_NO Year/Air Strip East_NO Product_1_poly.shp'

airstrip_west_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/University of Md._Aspen_Wye Angus/Boundary_NO Year/Air strip West_NO Product_1_poly.shp'

hayfield_middle_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/University of Md._Aspen_Wye Angus/Boundary_NO Year/Hayfield Middle_NO Product_1_poly.shp'

knowlton_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/University of Md._Aspen_Wye Angus/Boundary_NO Year/Knowlton_NO Product_1_poly.shp'

little_middle_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/University of Md._Aspen_Wye Angus/Boundary_NO Year/Little Middle_NO Product_1_poly.shp'

middle_field_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/University of Md._Aspen_Wye Angus/Boundary_NO Year/Middle Field_NO Product_1_poly.shp'

organic1_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/University of Md._Aspen_Wye Angus/Boundary_NO Year/Organic 1_NO Product_1_poly.shp'

organic2_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/University of Md._Aspen_Wye Angus/Boundary_NO Year/Organic 2_NO Product_1_poly.shp'

point_field_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/University of Md._Aspen_Wye Angus/Boundary_NO Year/Point Field_NO Product_1_poly.shp'

river_house_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/University of Md._Aspen_Wye Angus/Boundary_NO Year/River House_NO Product_1_poly.shp'

specter_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/University of Md._Aspen_Wye Angus/Boundary_NO Year/Specter_NO Product_1_poly.shp'

wi1_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/University of Md._Aspen_Wye Angus/Boundary_NO Year/WI-1_NO Product_1_poly.shp'


b_01_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_B-RANGE/Boundary_NO Year/B-01_NO Product_1_poly.shp'

b_05_08_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_B-RANGE/Boundary_NO Year/B-05,06,07,08_NO Product_1_poly.shp'


c04_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_C-Range/Boundary_NO Year/C-04_NO Product_1_poly.shp'

c09_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_C-Range/Boundary_NO Year/C-09_NO Product_1_poly.shp'

c10_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_C-Range/Boundary_NO Year/C-10_NO Product_1_poly.shp'

c10a_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_C-Range/Boundary_NO Year/C-10A_NO Product_1_poly.shp'


d03_04_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_D-range/Boundary_NO Year/D-03 04_NO Product_1_poly.shp'

d06_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_D-range/Boundary_NO Year/D-06_NO Product_1_poly.shp'


e01_02_03_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_E-range/Boundary_NO Year/E-01,02,03_NO Product_1_poly.shp'

e05_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_E-range/Boundary_NO Year/E-05_NO Product_1_poly.shp'


f01_wo_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_F-Range/Boundary_NO Year/F-01 WO_NO Product_1_poly.shp'

f01_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_F-Range/Boundary_NO Year/F-01_NO Product_1_poly.shp'


h02_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_H-Range/Boundary_NO Year/H-02_NO Product_1_poly.shp'

h04_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_H-Range/Boundary_NO Year/H-04_NO Product_1_poly.shp'

h05_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_H-Range/Boundary_NO Year/H-05_NO Product_1_poly.shp'

h06_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_H-Range/Boundary_NO Year/H-06_NO Product_1_poly.shp'


i04_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_I-Range/Boundary_NO Year/I-04_NO Product_1_poly.shp'

i06_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_I-Range/Boundary_NO Year/I-06_NO Product_1_poly.shp'

i07_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_I-Range/Boundary_NO Year/I-07_NO Product_1_poly.shp'

i08_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_I-Range/Boundary_NO Year/I-08_NO Product_1_poly.shp'


j01_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_J-RANGE/Boundary_NO Year/J-01_NO Product_1_poly.shp'

j02_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_J-RANGE/Boundary_NO Year/J-02_NO Product_1_poly.shp'

j03_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_J-RANGE/Boundary_NO Year/J-03_NO Product_1_poly.shp'

j04_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_J-RANGE/Boundary_NO Year/J-04_NO Product_1_poly.shp'

j04a_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_J-RANGE/Boundary_NO Year/J-04A_NO Product_1_poly.shp'

j05_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_J-RANGE/Boundary_NO Year/J-05_NO Product_1_poly.shp'

j05a_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_J-RANGE/Boundary_NO Year/J-05A_NO Product_1_poly.shp'

j06_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_J-RANGE/Boundary_NO Year/J-06_NO Product_1_poly.shp'

j07_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_J-RANGE/Boundary_NO Year/J-07_NO Product_1_poly.shp'

j08_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_J-RANGE/Boundary_NO Year/J-08_NO Product_1_poly.shp'

j09_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_J-RANGE/Boundary_NO Year/J-09_NO Product_1_poly.shp'

j10_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_J-RANGE/Boundary_NO Year/J-10_NO Product_1_poly.shp'


k01_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_K-RANGE/Boundary_NO Year/K-01_NO Product_1_poly.shp'

k02_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_K-RANGE/Boundary_NO Year/K-02_NO Product_1_poly.shp'

k03_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_K-RANGE/Boundary_NO Year/K-03_NO Product_1_poly.shp'

k04_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_K-RANGE/Boundary_NO Year/K-04_NO Product_1_poly.shp'

k05_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_K-RANGE/Boundary_NO Year/K-05_NO Product_1_poly.shp'

k0506_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_K-RANGE/Boundary_NO Year/K-05,06_NO Product_1_poly.shp'

k06_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_K-RANGE/Boundary_NO Year/K-06_NO Product_1_poly.shp'

k07_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_K-RANGE/Boundary_NO Year/K-07_NO Product_1_poly.shp'

k11_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_K-RANGE/Boundary_NO Year/K-11_NO Product_1_poly.shp'

k13_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_K-RANGE/Boundary_NO Year/K-13_NO Product_1_poly.shp'


manor_house_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_Manor House/Boundary_NO Year/Manor House_NO Product_1_poly.shp'


t01_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_T-RANGE/Boundary_NO Year/T-01_NO Product_1_poly.shp'

t02_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_T-RANGE/Boundary_NO Year/T-02_NO Product_1_poly.shp'

t06_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_T-RANGE/Boundary_NO Year/T-06_NO Product_1_poly.shp'

t08_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_T-RANGE/Boundary_NO Year/T-08_NO Product_1_poly.shp'

t08_09_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_T-RANGE/Boundary_NO Year/T-08-09_NO Product_1_poly.shp'

t09_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_T-RANGE/Boundary_NO Year/T-09_NO Product_1_poly.shp'

t10_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_T-RANGE/Boundary_NO Year/T-10_NO Product_1_poly.shp'

t11_12_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_T-RANGE/Boundary_NO Year/T-11,12_NO Product_1_poly.shp'

t12_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_T-RANGE/Boundary_NO Year/T-12_NO Product_1_poly.shp'

t13_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_T-RANGE/Boundary_NO Year/T-13_NO Product_1_poly.shp'

wi_02_file = './Field Boundaries (shapefiles)-20220807T203045Z-001/New Boundary Only (shapefiles)/Wye Research Center_Wye Island/Boundary_NO Year/WI-02_NO Product_1_poly.shp'

# %%
airstrip_east = gpd.read_file(airstrip_east_file) 
airstrip_west = gpd.read_file(airstrip_west_file)
hayfield_middle = gpd.read_file(hayfield_middle_file)
knowlton = gpd.read_file(knowlton_file)
little_middle = gpd.read_file(little_middle_file)
middle_field = gpd.read_file(middle_field_file)
organic1 = gpd.read_file(organic1_file)
organic2 = gpd.read_file(organic2_file)
point_field = gpd.read_file(point_field_file)
river_house = gpd.read_file(river_house_file)
specter = gpd.read_file(specter_file)
wi1 = gpd.read_file(wi1_file)
b_01 = gpd.read_file(b_01_file)
b_05_08 = gpd.read_file(b_05_08_file)
c04 = gpd.read_file(c04_file)
c09 = gpd.read_file(c09_file)
c10 = gpd.read_file(c10_file)
c10a = gpd.read_file(c10a_file)
d03_04 = gpd.read_file(d03_04_file)
d06 = gpd.read_file(d06_file)
e01_02_03 = gpd.read_file(e01_02_03_file)
e05_file = gpd.read_file(e05_file)
f01_wo = gpd.read_file(f01_wo_file)
f01 = gpd.read_file(f01_file) 
h02 = gpd.read_file(h02_file) 
h04 = gpd.read_file(h04_file)
h05 = gpd.read_file(h05_file)
h06 = gpd.read_file(h06_file)
i04 = gpd.read_file(i04_file)
i06 = gpd.read_file(i06_file)
i07 = gpd.read_file(i07_file)
i08 = gpd.read_file(i08_file)
j01 = gpd.read_file(j01_file)
j02 = gpd.read_file(j02_file)
j03 = gpd.read_file(j03_file)
j04 = gpd.read_file(j04_file)
j04a = gpd.read_file(j04a_file)
j05 = gpd.read_file(j05_file)
j05a = gpd.read_file(j05a_file)
j06 = gpd.read_file(j06_file)
j07 = gpd.read_file(j07_file)
j08 = gpd.read_file(j08_file)
j09 = gpd.read_file(j09_file)
j10 = gpd.read_file(j10_file)
k01 = gpd.read_file(k01_file)
k02 = gpd.read_file(k02_file)
k03 = gpd.read_file(k03_file)
k04 = gpd.read_file(k04_file)
k05 = gpd.read_file(k05_file)
k0506 = gpd.read_file(k0506_file)
k06 = gpd.read_file(k06_file)
k07 = gpd.read_file(k07_file)
k11 = gpd.read_file(k11_file)
k13 = gpd.read_file(k13_file)
manor_house = gpd.read_file(manor_house_file)
t01 = gpd.read_file(t01_file)
t02 = gpd.read_file(t02_file)
t06 = gpd.read_file(t06_file)
t08 = gpd.read_file(t08_file)
t08_09 = gpd.read_file(t08_09_file)
t09 = gpd.read_file(t09_file)
t10 = gpd.read_file(t10_file)
t11_12 = gpd.read_file(t11_12_file)
t12 = gpd.read_file(t12_file)
t13 = gpd.read_file(t13_file)
wi_02 = gpd.read_file(wi_02_file)

# %%
boundary_fields = pd.concat([airstrip_east, airstrip_west,hayfield_middle,knowlton,little_middle,middle_field,organic1,organic2,point_field,river_house,specter,wi1,b_01,b_05_08,c04
,c09
,c10
,c10a,d03_04
,d06
,e01_02_03
,e05_file
,f01_wo
,f01
,h02
,h04
,h05
,h06,i04
,i06
,i07
,i08
,j01
,j02
,j03
,j04
,j04a
,j05
,j05a
,j06
,j07
,j08
,j09
,j10
,k01
,k02
,k03
,k04
,k05
,k0506
,k06
,k07
,k11
,k13
,manor_house
,t01
,t02
,t06
,t08
,t08_09
,t09
,t10
,t11_12
,t12
,t13
,wi_02], axis=0)

# %%
boundary_fields.head()

# %%
boundary_fields = boundary_fields.reset_index(drop=True)
boundary_fields.head()

# %%
print(boundary_fields.Field.unique())
print("Number of Fields:",len(boundary_fields.Field.unique()))

# %%
print(df_2019.Field.unique())
print("Number of Fields:",len(df_2019.Field.unique()))

# %%
#list of Boundary fields not in crop data
out = boundary_fields.loc[~boundary_fields.Field.isin(df_2019.Field)]
out.Field.unique()

# %%
out.head()

# %% [markdown]
# # Spatial join field boundaries to points

# %%
#join_df = df_2019.sjoin(boundary_fields,how="inner", predicate='intersects')
join_df = gpd.sjoin(df_2019, boundary_fields)
join_df.head()

# %% [markdown]
# # Create dataset for each individual crop type

# %%
print("Crop Type:",join_df.Product_left.unique())
print("Crop Mapping Number:",join_df.Product_Cat.unique())
l1 = join_df.Product_left.unique()
l2 = join_df.Product_Cat.unique()
crops = dict(zip(l2,l1))
print(crops)

# %%
AG48X7 = join_df[join_df["Product_Cat"] == 0]
corn = join_df[df_2019["Product_Cat"] == 1]
P0843AM = join_df[join_df["Product_Cat"] == 2]
P1197AM = join_df[join_df["Product_Cat"] == 3]
P42T14L = join_df[join_df["Product_Cat"] == 4]
Soyabeans = join_df[join_df["Product_Cat"] == 5]
wheat = join_df[join_df["Product_Cat"] == 6]

# %%
#AG48X7
#corn
#P0843AM
#P1197AM
#P42T14L
#Soyabeans
#wheat

# %%
#pip install sklearn-xarray
import matplotlib.pyplot as plt
import numpy as np
from geowombat.ml import fit, predict, fit_predict
from sklearn_xarray.preprocessing import Featurizer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
AG48X7 = AG48X7[['Product_Cat','Field_Cat','abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation','yield']]
corn = corn[['Product_Cat','Field_Cat','abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation','yield']]
P0843AM = P0843AM[['Product_Cat','Field_Cat','abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation','yield']]
P1197AM = P1197AM[['Product_Cat','Field_Cat','abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation','yield']]
P42T14L = P42T14L[['Product_Cat','Field_Cat','abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation','yield']]
Soyabeans = Soyabeans[['Product_Cat','Field_Cat','abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation','yield']]
wheat = wheat[['Product_Cat','Field_Cat','abs_energy','absolute_sum_of_changes','autocorr_lag_1','autocorr_lag_2','count_above_mean','count_below_mean','doy_of_maximum_first_band','doy_of_maximum_last_band','doy_of_minimum_first_band','doy_of_minimum_last_band','kurtosis','linear_time_trend__intercept','linear_time_trend__pvalue','linear_time_trend__rvalue', 'linear_time_trend__slope', 'longest_strike_above_mean','longest_strike_below_mean','maximum','mean','mean_abs_change','mean_change','mean_second_derivative_central','median','minimum','quantile_q_0.05','quantile_q_0.95','ratio_beyond_r_sigma_r_1','ratio_beyond_r_sigma_r_2','ratio_beyond_r_sigma_r_3','ratio_value_number_to_time_series_length','skewness','standard_deviation','sum_values','symmetry_looking','ts_complexity_cid_ce','variance','variance_larger_than_standard_deviation','yield']]

# %%
AG48X7.head()
#corn.head()
#P0843AM.head()
#P1197AM.head()
#P42T14L.head()
#Soyabeans.head()
#wheat.head()

# %%
X_AG48X7 = AG48X7.iloc[:,:-1]
y_AG48X7 = AG48X7.iloc[:,[0,-1]]

X_corn = corn.iloc[:,:-1]
y_corn = corn.iloc[:,[0,-1]]

X_P0843AM = P0843AM.iloc[:,:-1]
y_P0843AM = P0843AM.iloc[:,[0,-1]]

X_P1197AM = P1197AM.iloc[:,:-1]
y_P1197AM = P1197AM.iloc[:,[0,-1]]

X_P42T14L = P42T14L.iloc[:,:-1]
y_P42T14L = P42T14L.iloc[:,[0,-1]]

X_Soyabeans = Soyabeans.iloc[:,:-1]
y_Soyabeans = Soyabeans.iloc[:,[0,-1]]

X_wheat = wheat.iloc[:,:-1]
y_wheat = wheat.iloc[:,[0,-1]]

# %% [markdown]
# # Create crop specific yeild models

# %% [markdown]
# # AG48X7

# %%
X_AG48X7.head()

# %%
X_train,X_test,y_train,y_test = train_test_split(X_AG48X7,y_AG48X7, test_size = 0.30, random_state = 50)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, criterion="squared_error",
                           bootstrap=True, oob_score=True, n_jobs=2,
                           random_state=42)

# Defining 3-dimensional hyperparameter space as a Python dictionary
hyperparameter_space = {'max_depth':[None,4,6,8,10,12,15,20], 
                        'min_samples_leaf':[1,2,4,6,8,10,20,30],
                        'max_features':['auto','sqrt','log2']}

from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(rf, param_grid=hyperparameter_space , 
                  scoring="neg_mean_squared_error",
                  n_jobs=2, cv=5, return_train_score=True)

gs.fit(X_train, y_train)

print("Optimal hyperparameter combination: ", gs.best_params_)
print("Mean cross-validated MSE or training score of the best_estimator: ",
       np.sqrt(-gs.best_score_))

gs.best_estimator_.fit(X_train, y_train)
y_pred = gs.best_estimator_.predict(X_test)

from sklearn.metrics import mean_squared_error as MSE
rmse_test = np.sqrt(MSE(y_test, y_pred))
print("Test score: ", np.round(rmse_test, 2))

from sklearn.metrics import r2_score
r2 = r2_score(y_test,gs.predict(X_test))
print(r2)

# %% [markdown]
# # corn

# %%
X_corn.head()

# %%
X_train,X_test,y_train,y_test = train_test_split(X_corn,y_corn, test_size = 0.30, random_state = 50)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, criterion="squared_error",
                           bootstrap=True, oob_score=True, n_jobs=2,
                           random_state=42)

# Defining 3-dimensional hyperparameter space as a Python dictionary
hyperparameter_space = {'max_depth':[None,4,6,8,10,12,15,20], 
                        'min_samples_leaf':[1,2,4,6,8,10,20,30],
                        'max_features':['auto','sqrt','log2']}

from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(rf, param_grid=hyperparameter_space , 
                  scoring="neg_mean_squared_error",
                  n_jobs=2, cv=5, return_train_score=True)

gs.fit(X_train, y_train)

print("Optimal hyperparameter combination: ", gs.best_params_)
print("Mean cross-validated MSE or training score of the best_estimator: ",
       np.sqrt(-gs.best_score_))

gs.best_estimator_.fit(X_train, y_train)
y_pred = gs.best_estimator_.predict(X_test)

from sklearn.metrics import mean_squared_error as MSE
rmse_test = np.sqrt(MSE(y_test, y_pred))
print("Test score: ", np.round(rmse_test, 2))

from sklearn.metrics import r2_score
r2 = r2_score(y_test,gs.predict(X_test))

# %%
print(r2)

# %% [markdown]
# # P0843AM

# %%
X_P0843AM.head()

# %%
X_train,X_test,y_train,y_test = train_test_split(X_P0843AM,y_P0843AM, test_size = 0.30, random_state = 50)

# %%
rf = RandomForestRegressor(n_estimators=100, criterion="squared_error",
                           bootstrap=True, oob_score=True, n_jobs=2,
                           random_state=42)

# Defining 3-dimensional hyperparameter space as a Python dictionary
hyperparameter_space = {'max_depth':[None,4,6,8,10,12,15,20], 
                        'min_samples_leaf':[1,2,4,6,8,10,20,30],
                        'max_features':['auto','sqrt','log2']}

from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(rf, param_grid=hyperparameter_space , 
                  scoring="neg_mean_squared_error",
                  n_jobs=2, cv=5, return_train_score=True)

gs.fit(X_train, y_train)

print("Optimal hyperparameter combination: ", gs.best_params_)
print("Mean cross-validated MSE or training score of the best_estimator: ",
       np.sqrt(-gs.best_score_))

gs.best_estimator_.fit(X_train, y_train)
y_pred = gs.best_estimator_.predict(X_test)

from sklearn.metrics import mean_squared_error as MSE
rmse_test = np.sqrt(MSE(y_test, y_pred))
print("Test score: ", np.round(rmse_test, 2))

from sklearn.metrics import r2_score
r2 = r2_score(y_test,gs.predict(X_test))
print(r2)

# %% [markdown]
# # P1197AM

# %%
X_P1197AM.head()

# %%
X_train,X_test,y_train,y_test = train_test_split(X_P1197AM,y_P1197AM, test_size = 0.30, random_state = 50)

# %%
rf = RandomForestRegressor(n_estimators=100, criterion="squared_error",
                           bootstrap=True, oob_score=True, n_jobs=2,
                           random_state=42)

# Defining 3-dimensional hyperparameter space as a Python dictionary
hyperparameter_space = {'max_depth':[None,4,6,8,10,12,15,20], 
                        'min_samples_leaf':[1,2,4,6,8,10,20,30],
                        'max_features':['auto','sqrt','log2']}

from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(rf, param_grid=hyperparameter_space , 
                  scoring="neg_mean_squared_error",
                  n_jobs=2, cv=5, return_train_score=True)

gs.fit(X_train, y_train)

print("Optimal hyperparameter combination: ", gs.best_params_)
print("Mean cross-validated MSE or training score of the best_estimator: ",
       np.sqrt(-gs.best_score_))

gs.best_estimator_.fit(X_train, y_train)
y_pred = gs.best_estimator_.predict(X_test)

from sklearn.metrics import mean_squared_error as MSE
rmse_test = np.sqrt(MSE(y_test, y_pred))
print("Test score: ", np.round(rmse_test, 2))

from sklearn.metrics import r2_score
r2 = r2_score(y_test,gs.predict(X_test))
print(r2)

# %% [markdown]
# # P42T14L

# %%
X_P42T14L.head()

# %%
X_train,X_test,y_train,y_test = train_test_split(X_P42T14L,y_P42T14L, test_size = 0.30, random_state = 50)

# %%
rf = RandomForestRegressor(n_estimators=100, criterion="squared_error",
                           bootstrap=True, oob_score=True, n_jobs=2,
                           random_state=42)

# Defining 3-dimensional hyperparameter space as a Python dictionary
hyperparameter_space = {'max_depth':[None,4,6,8,10,12,15,20], 
                        'min_samples_leaf':[1,2,4,6,8,10,20,30],
                        'max_features':['auto','sqrt','log2']}

from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(rf, param_grid=hyperparameter_space , 
                  scoring="neg_mean_squared_error",
                  n_jobs=2, cv=5, return_train_score=True)

gs.fit(X_train, y_train)

print("Optimal hyperparameter combination: ", gs.best_params_)
print("Mean cross-validated MSE or training score of the best_estimator: ",
       np.sqrt(-gs.best_score_))

gs.best_estimator_.fit(X_train, y_train)
y_pred = gs.best_estimator_.predict(X_test)

from sklearn.metrics import mean_squared_error as MSE
rmse_test = np.sqrt(MSE(y_test, y_pred))
print("Test score: ", np.round(rmse_test, 2))

from sklearn.metrics import r2_score
r2 = r2_score(y_test,gs.predict(X_test))
print(r2)

# %% [markdown]
# # Soyabeans

# %%
X_Soyabeans.head()

# %%
X_train,X_test,y_train,y_test = train_test_split(X_Soyabeans,y_Soyabeans, test_size = 0.30, random_state = 50)

# %%
rf = RandomForestRegressor(n_estimators=100, criterion="squared_error",
                           bootstrap=True, oob_score=True, n_jobs=2,
                           random_state=42)

# Defining 3-dimensional hyperparameter space as a Python dictionary
hyperparameter_space = {'max_depth':[None,4,6,8,10,12,15,20], 
                        'min_samples_leaf':[1,2,4,6,8,10,20,30],
                        'max_features':['auto','sqrt','log2']}

from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(rf, param_grid=hyperparameter_space , 
                  scoring="neg_mean_squared_error",
                  n_jobs=2, cv=5, return_train_score=True)

gs.fit(X_train, y_train)

print("Optimal hyperparameter combination: ", gs.best_params_)
print("Mean cross-validated MSE or training score of the best_estimator: ",
       np.sqrt(-gs.best_score_))

gs.best_estimator_.fit(X_train, y_train)
y_pred = gs.best_estimator_.predict(X_test)

from sklearn.metrics import mean_squared_error as MSE
rmse_test = np.sqrt(MSE(y_test, y_pred))
print("Test score: ", np.round(rmse_test, 2))

from sklearn.metrics import r2_score
r2 = r2_score(y_test,gs.predict(X_test))
print(r2)

# %% [markdown]
# # wheat

# %%
X_wheat.head()

# %%
X_train,X_test,y_train,y_test = train_test_split(X_wheat,y_wheat, test_size = 0.30, random_state = 50)

# %%
rf = RandomForestRegressor(n_estimators=100, criterion="squared_error",
                           bootstrap=True, oob_score=True, n_jobs=2,
                           random_state=42)

# Defining 3-dimensional hyperparameter space as a Python dictionary
hyperparameter_space = {'max_depth':[None,4,6,8,10,12,15,20], 
                        'min_samples_leaf':[1,2,4,6,8,10,20,30],
                        'max_features':['auto','sqrt','log2']}

from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(rf, param_grid=hyperparameter_space , 
                  scoring="neg_mean_squared_error",
                  n_jobs=2, cv=5, return_train_score=True)

gs.fit(X_train, y_train)

print("Optimal hyperparameter combination: ", gs.best_params_)
print("Mean cross-validated MSE or training score of the best_estimator: ",
       np.sqrt(-gs.best_score_))

gs.best_estimator_.fit(X_train, y_train)
y_pred = gs.best_estimator_.predict(X_test)

from sklearn.metrics import mean_squared_error as MSE
rmse_test = np.sqrt(MSE(y_test, y_pred))
print("Test score: ", np.round(rmse_test, 2))

from sklearn.metrics import r2_score
r2 = r2_score(y_test,gs.predict(X_test))
print(r2)

# %%
print(r2)
